# %% [markdown]
# ## Questionamentos
# 1 - Qual o valor médio recebido por cidade ao longo do tempo?
# 2 - Qual a porcentagem de pagamantos feitos em atraso por cidade?
# 3 - Qual o tempo médio de atraso do apagamento por cidade?
#
# LINK: http://ivs.ipea.gov.br/index.php/pt/biblioteca

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/marcos/Desktop/dados/clean_data/newdataset.csv')

# %%
df
# Out:
#       Unnamed: 0  MES_REFERENCIA  MES_COMPETENCIA  UF  CODIGO_MUNICIPIO_SIAFI  \
# 0              0          201301           201202  DF                    9701
# 1              1          201301           201203  DF                    9701
# 2              2          201301           201204  DF                    9701
# 3              3          201301           201205  DF                    9701
# 4              4          201301           201206  DF                    9701
# ...          ...             ...              ...  ..                     ...
# 9994        9994          201301           201301  DF                    9701
# 9995        9995          201301           201301  DF                    9701
# 9996        9996          201301           201301  DF                    9701
# 9997        9997          201301           201301  DF                    9701
# 9998        9998          201301           201301  DF                    9701
#
#      NOME_MUNICIPIO  NIS_FAVORECIDO                     NOME_FAVORECIDO  \
# 0          BRASILIA    1.668612e+10            VALNI ESTEVES DE AZEVEDO
# 1          BRASILIA    1.668612e+10            VALNI ESTEVES DE AZEVEDO
# 2          BRASILIA    1.668612e+10            VALNI ESTEVES DE AZEVEDO
# 3          BRASILIA    1.668612e+10            VALNI ESTEVES DE AZEVEDO
# 4          BRASILIA    2.125903e+10          ANA PAULA PEREIRA DA SILVA
# ...             ...             ...                                 ...
# 9994       BRASILIA    1.262746e+10          AURENI FERREIRA DOS SANTOS
# 9995       BRASILIA    1.613855e+10             AURENI LACERDA DE SOUSA
# 9996       BRASILIA    1.614167e+10  AURENI PEREIRA DE FIGUEIREDO SOUSA
# 9997       BRASILIA    1.601549e+10             AURENI RODRIGUES BORGES
# 9998       BRASILIA    1.607934e+10                     AURENI SILVA SA
#
#       VALOR_PARCELA      LAT      LON
# 0             102.0 -15.7795 -47.9297
# 1             102.0 -15.7795 -47.9297
# 2             102.0 -15.7795 -47.9297
# 3             102.0 -15.7795 -47.9297
# 4              64.0 -15.7795 -47.9297
# ...             ...      ...      ...
# 9994          212.0 -15.7795 -47.9297
# 9995          216.0 -15.7795 -47.9297
# 9996           70.0 -15.7795 -47.9297
# 9997          102.0 -15.7795 -47.9297
# 9998           96.0 -15.7795 -47.9297
#
# [9999 rows x 11 columns]

# %%
df.groupby('CODIGO_MUNICIPIO_SIAFI').head(1)
# Out:
#    Unnamed: 0  MES_REFERENCIA  MES_COMPETENCIA  UF  CODIGO_MUNICIPIO_SIAFI  \
# 0           0          201301           201202  DF                    9701
#
#   NOME_MUNICIPIO  NIS_FAVORECIDO           NOME_FAVORECIDO  VALOR_PARCELA  \
# 0       BRASILIA    1.668612e+10  VALNI ESTEVES DE AZEVEDO          102.0
#
#        LAT      LON
# 0 -15.7795 -47.9297
