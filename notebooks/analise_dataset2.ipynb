# %%
import pandas as pd

# %%
dataframe = pd.read_csv('/home/marcos/Desktop/dados/clean_data/datasetCompleto2.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-e5ad5f69c039> in <module>
# ----> 1 dataframe = pd.read_csv('/home/marcos/Desktop/dados/clean_data/datasetCompleto2.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
#del dataframe['Unnamed: 0']
dataframe.groupby('CODIGO_MUNICIPIO_SIAFI').head(1)
# Out:
#           MES_REFERENCIA  MES_COMPETENCIA  UF  CODIGO_MUNICIPIO_SIAFI  \
# 0                 201301           201202  DF                    9701
# 6713370           201301           201206  GO                    9205
# 6895385           201301           201206  GO                      55
# 7068446           201301           201206  GO                    9677
# 7612514           201301           201206  GO                    1066
# 8222253           201301           201207  GO                    1052
# 9573520           201301           201207  GO                    9325
# 9880364           201301           201207  GO                    9445
# 10992484          201301           201208  MG                    4185
# 11209174          201301           201208  MG                     578
# 11260059          201301           201209  GO                      77
# 11656035          201301           201209  GO                    9359
# ...
