# %% [markdown]
# # Questionamentos
# #### 1 - Qual o valor médio recebido por cidade ao longo do tempo?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd

# %% [markdown]
# ## Municipios MG

# %%
mg = gpd.read_file('/home/marcos/Desktop/dados/ride_shp/Shapes_RIDE_DF/municipios_mg.shp')
mg
# Out:
#      ID CD_GEOCODM        NM_MUNICIP  \
# 0   715    3109303           BURITIS
# 1   717    3109451  CABECEIRA GRANDE
# 2  1440    3170404              UNAÍ
#
#                                             geometry
# 0  POLYGON ((-46.89702 -15.40228, -46.89068 -15.4...
# 1  POLYGON ((-46.98980 -16.12038, -46.98933 -16.1...
# 2  POLYGON ((-46.92935 -15.91122, -46.85163 -15.8...

# %%
mg.area
# Out:
# 0    0.440005
# 1    0.087113
# 2    0.714514
# dtype: float64

# %%
mg.plot(figsize=(10,9),edgecolor='black', column='CD_GEOCODM')
plt.show()

# %% [markdown]
# ## Municipios Goiás

# %%
go = gpd.read_file('/home/marcos/Desktop/dados/ride_shp/Shapes_RIDE_DF/municipios_goias.shp')
go
# Out:
#      ID CD_GEOCODM                   NM_MUNICIP  \
# 0   360    5200100                    ABADIÂNIA
# 1   363    5200175           ÁGUA FRIA DE GOIÁS
# 2   365    5200258        ÁGUAS LINDAS DE GOIÁS
# 3   366    5200308                     ALEXÂNIA
# 4   400    5204003                   CABECEIRAS
# 5   423    5205497             CIDADE OCIDENTAL
# 6   424    5205513          COCALZINHO DE GOIÁS
# 7   427    5205802             CORUMBÁ DE GOIÁS
# 8   429    5206206                   CRISTALINA
# 9   446    5208004                      FORMOSA
# 10  493    5212501                     LUZIÂNIA
# 11  500    5213053              MIMOSO DE GOIÁS
# 12  525    5215231                    NOVO GAMA
# 13  530    5215603               PADRE BERNARDO
# 14  543    5217302                  PIRENÓPOLIS
# 15  545    5217609                   PLANALTINA
# 16  571    5219753  SANTO ANTÔNIO DO DESCOBERTO
# 17  599    5221858          VALPARAÍSO DE GOIÁS
# ...

# %%
go.plot(column='CD_GEOCODM',figsize=(10,9),edgecolor='black')
plt.show()

# %% [markdown]
# ## Limite RIDE

# %%
ride = gpd.read_file('/home/marcos/Desktop/dados/ride_shp/Shapes_RIDE_DF/limite_ride_df.shp')
ride
# Out:
#      RM                                           geometry
# 0  RIDE  POLYGON ((-49.21750 -15.86002, -49.21717 -15.8...

# %%
ride.plot(color=None,figsize=(10,9),edgecolor='black')
plt.show()

# %% [markdown]
# ## RM RIDE DF UDH

# %%
pd.set_option("display.max_rows", 2000)
var = gpd.read_file('/home/marcos/Desktop/dados/ride_shp/Shapes_RIDE_DF/rm_ride_df_udh.shp')
var.groupby('NM_MUNICIP').head(1)
# Out:
#          UDH_ATLAS   REGIONAL CD_GEOCODM                   NM_MUNICIP  \
# 0    1530010800001  353001010    5300108                     BRASÍLIA
# 233  1310930300001       None    3109303                      BURITIS
# 234  1317040400001       None    3170404                         UNAÍ
# 251  1520010000001       None    5200100                    ABADIÂNIA
# 252  1520017500001       None    5200175           ÁGUA FRIA DE GOIÁS
# 253  1520025800001       None    5200258        ÁGUAS LINDAS DE GOIÁS
# 262  1520030800001       None    5200308                     ALEXÂNIA
# 263  1520400300001       None    5204003                   CABECEIRAS
# 264  1520549700002       None    5205497             CIDADE OCIDENTAL
# 271  1520551300001       None    5205513          COCALZINHO DE GOIÁS
# 272  1520580200001       None    5205802             CORUMBÁ DE GOIÁS
# 273  1520620600001       None    5206206                   CRISTALINA
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-d6d1bcde948f> in <module>
# ----> 1 group.shape
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'shape'

# %%
var.plot(column='CD_GEOCODM',figsize=(15,10),edgecolor='white')
plt.show()

# %% [markdown]
# ## Merge com dataframe de teste

# %%
#Dataframe de teste com as cidades
df = pd.read_csv('/home/marcos/Desktop/dados/clean_data/newdataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  MES_REFERENCIA  MES_COMPETENCIA  UF  CODIGO_MUNICIPIO_SIAFI  \
# 0           0          201301           201202  DF                    9701
# 1           1          201301           201203  DF                    9701
# 2           2          201301           201204  DF                    9701
# 3           3          201301           201205  DF                    9701
# 4           4          201301           201206  DF                    9701
#
#   NOME_MUNICIPIO  NIS_FAVORECIDO             NOME_FAVORECIDO  VALOR_PARCELA  \
# 0       BRASILIA    1.668612e+10    VALNI ESTEVES DE AZEVEDO          102.0
# 1       BRASILIA    1.668612e+10    VALNI ESTEVES DE AZEVEDO          102.0
# 2       BRASILIA    1.668612e+10    VALNI ESTEVES DE AZEVEDO          102.0
# 3       BRASILIA    1.668612e+10    VALNI ESTEVES DE AZEVEDO          102.0
# 4       BRASILIA    2.125903e+10  ANA PAULA PEREIRA DA SILVA           64.0
#
#        LAT      LON
# 0 -15.7795 -47.9297
# ...

# %%
#Remoção de algumas colunas
# del df['NOME_FAVORECIDO']
# del df['LAT']
# del df['LON']
# del df['Unnamed: 0']
df.head()
# Out:
#    MES_REFERENCIA  MES_COMPETENCIA  UF  CODIGO_MUNICIPIO_SIAFI NOME_MUNICIPIO  \
# 0          201301           201202  DF                    9701       BRASILIA
# 1          201301           201203  DF                    9701       BRASILIA
# 2          201301           201204  DF                    9701       BRASILIA
# 3          201301           201205  DF                    9701       BRASILIA
# 4          201301           201206  DF                    9701       BRASILIA
#
#    NIS_FAVORECIDO  VALOR_PARCELA
# 0    1.668612e+10          102.0
# 1    1.668612e+10          102.0
# 2    1.668612e+10          102.0
# 3    1.668612e+10          102.0
# 4    2.125903e+10           64.0

# %%
df['NOME_MUNICIPIO'] = 'BRASÍLIA'

# %%
df_result = pd.merge(left=df,right=var,left_on='NOME_MUNICIPIO', right_on='NM_MUNICIP',how='inner')

# %%
df_result
# del df_result['UDH_ATLAS']
# del df_result['NM_MUNICIP']

# %%
#Criando geodataframe
geoBsb = gpd.GeoDataFrame(df_result)
geoBsb.head()
# Out:
#    MES_REFERENCIA  MES_COMPETENCIA  UF  CODIGO_MUNICIPIO_SIAFI NOME_MUNICIPIO  \
# 0          201301           201202  DF                    9701       BRASÍLIA
# 1          201301           201202  DF                    9701       BRASÍLIA
# 2          201301           201202  DF                    9701       BRASÍLIA
# 3          201301           201202  DF                    9701       BRASÍLIA
# 4          201301           201202  DF                    9701       BRASÍLIA
#
#    NIS_FAVORECIDO  VALOR_PARCELA   REGIONAL CD_GEOCODM  \
# 0    1.668612e+10          102.0  353001010    5300108
# 1    1.668612e+10          102.0  353001019    5300108
# 2    1.668612e+10          102.0  353001011    5300108
# 3    1.668612e+10          102.0  353001006    5300108
# 4    1.668612e+10          102.0  353001004    5300108
#
#                                             geometry
# 0  POLYGON ((-48.11521 -15.83216, -48.11528 -15.8...
# 1  POLYGON ((-47.75060 -15.91208, -47.75078 -15.9...
# ...

# %%
geoBsb.plot(column='REGIONAL',figsize=(15,10),edgecolor='white')
plt.show()

# %%
teste =  gpd.read_file('/home/marcos/Desktop/dados/clean_data/bsb.shp')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e5825908c778> in <module>
# ----> 1 teste =  gpd.read_file('/home/marcos/Desktop/dados/clean_data/bsb.shp')
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/io/file.py in read_file(filename, bbox, mask, rows, **kwargs)
#     125
#     126             columns = list(features.meta["schema"]["properties"]) + ["geometry"]
# --> 127             gdf = GeoDataFrame.from_features(f_filt, crs=crs, columns=columns)
#     128
#     129     return gdf
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/geodataframe.py in from_features(cls, features, crs, columns)
#     292
#     293         rows = []
# --> 294         for f in features_lst:
#     295             if hasattr(f, "__geo_interface__"):
#     296                 f = f.__geo_interface__
#
# fiona/ogrext.pyx in fiona.ogrext.Iterator.__next__()
#
# ...

# %% [markdown]
# ## Municipios GO - Completo

# %%
dfgoall = gpd.read_file('/home/marcos/Desktop/dados/go_municipios/52MUE250GC_SIR.shp')

# %%
dfgoall.shape
# Out:
# (246, 3)
