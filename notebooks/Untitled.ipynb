# %%
import numpy as np
import pandas as pd
from IPython.core.display import HTML

import bokeh
print('Bokeh version:', bokeh.__version__)

from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.io import output_notebook
from bokeh.models import HoverTool
from bokeh.resources import CDN
from bokeh.embed import file_html
output_notebook()

df = pd.DataFrame(np.random.normal(0, 5, (100, 2)), columns=['x','y'])
source = ColumnDataSource(df)
hover = HoverTool(tooltips=[("x", "@x"), ("y", "@y")])
myplot = figure(plot_width=600, plot_height=400, tools='hover,box_zoom,box_select,crosshair,resize,reset')
myplot.circle('x', 'y', size=7, fill_alpha=0.5, source=source)
show(myplot, notebook_handle=True);
# Out:
# Bokeh version: 1.4.0
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-605687893013> in <module>
#      17 source = ColumnDataSource(df)
#      18 hover = HoverTool(tooltips=[("x", "@x"), ("y", "@y")])
# ---> 19 myplot = figure(plot_width=600, plot_height=400, tools='hover,box_zoom,box_select,crosshair,resize,reset')
#      20 myplot.circle('x', 'y', size=7, fill_alpha=0.5, source=source)
#      21 show(myplot, notebook_handle=True);
#
# ~/anaconda3/lib/python3.7/site-packages/bokeh/plotting/figure.py in figure(**kwargs)
#    1240
#    1241 def figure(**kwargs):
# -> 1242     return Figure(**kwargs)
#    1243 figure.__doc__ = Figure.__doc__
#    1244
#
# ~/anaconda3/lib/python3.7/site-packages/bokeh/plotting/figure.py in __init__(self, *arg, **kw)
#     162         _process_axis_and_grid(self, opts.y_axis_type, opts.y_axis_location, opts.y_minor_ticks, opts.y_axis_label, self.y_range, 1)
#     163
# --> 164         tool_objs, tool_map = _process_tools_arg(self, opts.tools, opts.tooltips)
#     165         self.add_tools(*tool_objs)
#     166         _process_active_tools(self.toolbar, tool_map, opts.active_drag, opts.active_inspect, opts.active_scroll, opts.active_tap)
#
# ~/anaconda3/lib/python3.7/site-packages/bokeh/plotting/helpers.py in _process_tools_arg(plot, tools, tooltips)
#     677             continue
#     678
# --> 679         tool_obj = _tool_from_string(tool)
#     680         tool_objs.append(tool_obj)
#     681         tool_map[tool] = tool_obj
#
# ~/anaconda3/lib/python3.7/site-packages/bokeh/plotting/helpers.py in _tool_from_string(name)
#     620             matches, text = known_tools, "possible"
#     621
# --> 622         raise ValueError("unexpected tool name '%s', %s tools are %s" % (name, text, nice_join(matches)))
#     623
#     624
#
# ValueError: unexpected tool name 'resize', similar tools are reset

# %%
myplot_html = file_html(myplot, CDN)
# this HTML code is very long (~30 K), the cell below doesn't show all the code in NBviewer
print(myplot_html)
