# %%
# Instalations
#!pip install geopandas
# !pip3 install datapane
# Out:
# Collecting datapane
#   Downloading https://files.pythonhosted.org/packages/ef/ed/fff85f2e22171f38afe07bc0f03d8af213518d13063508bb8047cd55a537/datapane-0.7.1-py3-none-any.whl (2.6MB)
#     100% |████████████████████████████████| 2.6MB 479kB/s ta 0:00:011
# Collecting importlib_resources<4.0.0,>=3.0.0 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/ba/03/0f9595c0c2ef12590877f3c47e5f579759ce5caf817f8256d5dcbd8a1177/importlib_resources-3.0.0-py2.py3-none-any.whl
# Collecting pandas<2.0.0,>=1.0.1 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/a7/f7/2adca20a7fa71b6a32f823bbd83992adeceab1d8bf72992bb7a55c69c19a/pandas-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (10.5MB)
#     100% |████████████████████████████████| 10.5MB 135kB/s ta 0:00:01
# Collecting plotly<5.0.0,>=4.8.1 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/bf/5f/47ab0d9d843c5be0f5c5bd891736a4c84fa45c3b0a0ddb6b6df7c098c66f/plotly-4.9.0-py2.py3-none-any.whl (12.9MB)
#     100% |████████████████████████████████| 12.9MB 117kB/s ta 0:00:01
# Collecting colorlog<5.0.0,>=4.1.0 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/2a/81/12d77537c82c5d46aa2721dfee25a0e873ef5920ebd0827152f411effb57/colorlog-4.2.1-py2.py3-none-any.whl
# Collecting packaging<21.0,>=20.3 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/46/19/c5ab91b1b05cfe63cccd5cfc971db9214c6dd6ced54e33c30d5af1d2bc43/packaging-20.4-py2.py3-none-any.whl
# Collecting altair<5.0.0,>=4.0.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/01/55/0bb2226e34f21fa549c3f4557b4f154a5632f61132a969da17c95ca8eab9/altair-4.1.0-py3-none-any.whl
# Collecting jinja2<3.0.0,>=2.11.1 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl
# Collecting stringcase<2.0.0,>=1.2.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/f3/1f/1241aa3d66e8dc1612427b17885f5fcd9c9ee3079fc0d28e9a3aeeb36fa3/stringcase-1.2.0.tar.gz
# Collecting requests-toolbelt<0.10.0,>=0.9.1 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 3.2MB/s eta 0:00:01
# Collecting requests<3.0.0,>=2.20.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl
# Collecting click-spinner<0.2.0,>=0.1.8 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/93/2a/04893832bfeddc2d40a7de2e8153b3085f12d63507d91a9cf0157dc3a1c2/click_spinner-0.1.10-py2.py3-none-any.whl
# Collecting pyarrow<0.18.0,>=0.17.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/70/9b/38ca9af13cdf5a806d250aea829f1e5e9262ae7e0cfa91cd3679690a8b66/pyarrow-0.17.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting click<8.0.0,>=7.0.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl
# Collecting furl<3.0.0,>=2.1.0 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/9f/c7/e9dc30914bf048bcd06284bb93d9650d318ecac8668b684fc41e975558ff/furl-2.1.0-py2.py3-none-any.whl
# Collecting jsonschema<4.0.0,>=3.2.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl
# Collecting nbconvert<6.0.0,>=5.6.1 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/79/6c/05a569e9f703d18aacb89b7ad6075b404e8a4afde2c26b73ca77bb644b14/nbconvert-5.6.1-py2.py3-none-any.whl
# Collecting flit-core<2.4.0,>=2.3.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/4b/3c/82798771fc1fd978c9225c5ae25eef45cb23b0df4728f208024a5b57901f/flit_core-2.3.0-py2.py3-none-any.whl
# Collecting ruamel.yaml<0.17.0,>=0.16.5 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/a6/92/59af3e38227b9cc14520bf1e59516d99ceca53e3b8448094248171e9432b/ruamel.yaml-0.16.10-py2.py3-none-any.whl
# Collecting tabulate<0.9.0,>=0.8.7 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/c4/f4/770ae9385990f5a19a91431163d262182d3203662ea2b5739d0fcfc080f1/tabulate-0.8.7-py3-none-any.whl
# Collecting bokeh<3.0.0,>=2.0.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/74/d9/7fceb4da358a0cda9f080ac12c5cd46ff2595afbe461f369000524b2881a/bokeh-2.1.1.tar.gz
# Collecting validators<0.17.0,>=0.16.0 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/c0/74/66419c1dad0c4e66b0c79f28d83f1259ed8648f35d8de10de8acff474f0f/validators-0.16.0.tar.gz
# Collecting numpy<2.0.0,>=1.18.0 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/22/e7/4b2bdddb99f5f631d8c1de259897c2b7d65dcfcc1e0a6fd17a7f62923500/numpy-1.19.1-cp36-cp36m-manylinux1_x86_64.whl (13.4MB)
#     100% |████████████████████████████████| 13.4MB 107kB/s ta 0:00:01
# Collecting lxml<5.0.0,>=4.5.2 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/79/37/d420b7fdc9a550bd29b8cfeacff3b38502d9600b09d7dfae9a69e623b891/lxml-4.5.2-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#     100% |████████████████████████████████| 5.5MB 259kB/s ta 0:00:01
# Collecting munch<3.0.0,>=2.5.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Collecting dacite<2.0.0,>=1.2.0 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/20/c2/8a82f9bda39fd43948f5104308e4feebe931ea550791a4ff5d1459fa9717/dacite-1.5.1-py3-none-any.whl
# Collecting matplotlib<4.0.0,>=3.1.0 (from datapane)
#   Downloading https://files.pythonhosted.org/packages/93/ae/81b1c98ae97350711adb021ee12ea678b37f608ec2faa35c3a7db11795fa/matplotlib-3.3.0-1-cp36-cp36m-manylinux1_x86_64.whl (11.5MB)
#     100% |████████████████████████████████| 11.5MB 124kB/s ta 0:00:01    92% |█████████████████████████████▋  | 10.6MB 5.3MB/s eta 0:00:01
# Collecting folium<0.12.0,>=0.11.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl
# Collecting PyYAML<6.0.0,>=5.3.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz
# Collecting toolz<0.11.0,>=0.10.0 (from datapane)
#   Using cached https://files.pythonhosted.org/packages/22/8e/037b9ba5c6a5739ef0dcde60578c64d49f45f64c5e5e886531bfbc39157f/toolz-0.10.0.tar.gz
# Collecting zipp>=0.4; python_version < "3.8" (from importlib_resources<4.0.0,>=3.0.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Collecting pytz>=2017.2 (from pandas<2.0.0,>=1.0.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl
# Collecting python-dateutil>=2.7.3 (from pandas<2.0.0,>=1.0.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting six (from plotly<5.0.0,>=4.8.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting retrying>=1.3.3 (from plotly<5.0.0,>=4.8.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Collecting pyparsing>=2.0.2 (from packaging<21.0,>=20.3->datapane)
#   Using cached https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl
# Collecting entrypoints (from altair<5.0.0,>=4.0.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting MarkupSafe>=0.23 (from jinja2<3.0.0,>=2.11.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests<3.0.0,>=2.20.0->datapane)
#   Downloading https://files.pythonhosted.org/packages/9f/f0/a391d1463ebb1b233795cabfc0ef38d3db4442339de68f847026199e69d7/urllib3-1.25.10-py2.py3-none-any.whl (127kB)
#     100% |████████████████████████████████| 133kB 3.9MB/s ta 0:00:01
# Collecting chardet<4,>=3.0.2 (from requests<3.0.0,>=2.20.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Collecting idna<3,>=2.5 (from requests<3.0.0,>=2.20.0->datapane)
#   Downloading https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 5.3MB/s ta 0:00:011
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.20.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl
# Collecting orderedmultidict>=1.0.1 (from furl<3.0.0,>=2.1.0->datapane)
#   Downloading https://files.pythonhosted.org/packages/04/16/5e95c70bda8fe6ea715005c0db8e602400bdba50ae3c72cb380eba551289/orderedmultidict-1.0.1-py2.py3-none-any.whl
# Collecting pyrsistent>=0.14.0 (from jsonschema<4.0.0,>=3.2.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/9f/0d/cbca4d0bbc5671822a59f270e4ce3f2195f8a899c97d0d5abb81b191efb5/pyrsistent-0.16.0.tar.gz
# Collecting attrs>=17.4.0 (from jsonschema<4.0.0,>=3.2.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting importlib-metadata; python_version < "3.8" (from jsonschema<4.0.0,>=3.2.0->datapane)
#   Downloading https://files.pythonhosted.org/packages/8e/58/cdea07eb51fc2b906db0968a94700866fc46249bdc75cac23f9d13168929/importlib_metadata-1.7.0-py2.py3-none-any.whl
# Collecting setuptools (from jsonschema<4.0.0,>=3.2.0->datapane)
#   Downloading https://files.pythonhosted.org/packages/ed/16/e9f5c5b86696da09298ea10c32d68ad8ea21f888e45b11aa9e615adda6c9/setuptools-49.2.1-py3-none-any.whl (789kB)
#     100% |████████████████████████████████| 798kB 1.5MB/s ta 0:00:01
# Collecting jupyter-core (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/63/0d/df2d17cdf389cea83e2efa9a4d32f7d527ba78667e0153a8e676e957b2f7/jupyter_core-4.6.3-py2.py3-none-any.whl
# Collecting testpath (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/1b/9e/1a170feaa54f22aeb5a5d16c9015e82234275a3c8ab630b552493f9cb8a9/testpath-0.4.4-py2.py3-none-any.whl
# Collecting pygments (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/2d/68/106af3ae51daf807e9cdcba6a90e518954eb8b70341cee52995540a53ead/Pygments-2.6.1-py3-none-any.whl
# Collecting defusedxml (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting nbformat>=4.4 (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/4d/d1/b568bd35f95321f152f594b3647cd080e96d3347843ff2fa34dce871b8bf/nbformat-5.0.7-py3-none-any.whl
# Collecting bleach (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/9a/1e/7d6cb3b27cd2c490558349ca5d5cc05b390b017da1c704cac807ac8bd9fb/bleach-3.1.5-py2.py3-none-any.whl
# Collecting traitlets>=4.2 (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/ca/ab/872a23e29cec3cf2594af7e857f18b687ad21039c1f9b922fac5b9b142d5/traitlets-4.3.3-py2.py3-none-any.whl
# Collecting pandocfilters>=1.4.1 (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting mistune<2,>=0.8.1 (from nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting pytoml (from flit-core<2.4.0,>=2.3.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/a5/47/c7f8a0f210ad18576840922e0b504f0b7f5f73aea4a52ab14c5b58517edf/pytoml-0.1.21-py2.py3-none-any.whl
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" (from ruamel.yaml<0.17.0,>=0.16.5->datapane)
#   Using cached https://files.pythonhosted.org/packages/53/77/4bcd63f362bcb6c8f4f06253c11f9772f64189bf08cf3f40c5ccbda9e561/ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting pillow>=4.0 (from bokeh<3.0.0,>=2.0.0->datapane)
#   Downloading https://files.pythonhosted.org/packages/30/bf/92385b4262178ca22b34f82e0e09c2922eb351fe39f3cc7b8ba9ea555b41/Pillow-7.2.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 599kB/s ta 0:00:01
# Collecting tornado>=5.1 (from bokeh<3.0.0,>=2.0.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz
# Collecting typing_extensions>=3.7.4 (from bokeh<3.0.0,>=2.0.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/0c/0e/3f026d0645d699e7320b59952146d56ad7c374e9cd72cd16e7c74e657a0f/typing_extensions-3.7.4.2-py3-none-any.whl
# Collecting decorator>=3.4.0 (from validators<0.17.0,>=0.16.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl
# Collecting dataclasses; python_version < "3.7" (from dacite<2.0.0,>=1.2.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/e1/d2/6f02df2616fd4016075f60157c7a0452b38d8f7938ae94343911e0fb0b09/dataclasses-0.7-py3-none-any.whl
# Collecting cycler>=0.10 (from matplotlib<4.0.0,>=3.1.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib<4.0.0,>=3.1.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/ae/23/147de658aabbf968324551ea22c0c13a00284c4ef49a77002e91f79657b7/kiwisolver-1.2.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting branca>=0.3.0 (from folium<0.12.0,>=0.11.0->datapane)
#   Using cached https://files.pythonhosted.org/packages/13/fb/9eacc24ba3216510c6b59a4ea1cd53d87f25ba76237d7f4393abeaf4c94e/branca-0.4.1-py3-none-any.whl
# Collecting ipython-genutils (from nbformat>=4.4->nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting webencodings (from bleach->nbconvert<6.0.0,>=5.6.1->datapane)
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Building wheels for collected packages: stringcase, bokeh, validators, PyYAML, toolz, retrying, pyrsistent, pandocfilters, tornado
#   Running setup.py bdist_wheel for stringcase ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/stringcase/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpro2y6zsrpip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for stringcase
#   Running setup.py clean for stringcase
#   Running setup.py bdist_wheel for bokeh ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/bokeh/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpjdyyos3kpip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for bokeh
#   Running setup.py clean for bokeh
#   Running setup.py bdist_wheel for validators ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/validators/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpubimwrxzpip-wheel- --python-tag cp36:
#   /usr/lib/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: 'build_requires'
#     warnings.warn(msg)
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for validators
#   Running setup.py clean for validators
#   Running setup.py bdist_wheel for PyYAML ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/PyYAML/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpiz_fospspip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for PyYAML
#   Running setup.py clean for PyYAML
#   Running setup.py bdist_wheel for toolz ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/toolz/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpetocifgjpip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for toolz
#   Running setup.py clean for toolz
#   Running setup.py bdist_wheel for retrying ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/retrying/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpxn7di2kypip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for retrying
#   Running setup.py clean for retrying
#   Running setup.py bdist_wheel for pyrsistent ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/pyrsistent/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmp1upvkb5opip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for pyrsistent
#   Running setup.py clean for pyrsistent
#   Running setup.py bdist_wheel for pandocfilters ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/pandocfilters/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmpc2i92iytpip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for pandocfilters
#   Running setup.py clean for pandocfilters
#   Running setup.py bdist_wheel for tornado ... error
#   Complete output from command /usr/bin/python3 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-_o650hhk/tornado/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/tmp7wxf7tw0pip-wheel- --python-tag cp36:
#   usage: -c [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: -c --help [cmd1 cmd2 ...]
#      or: -c --help-commands
#      or: -c cmd --help
#
#   error: invalid command 'bdist_wheel'
#
#   ----------------------------------------
#   Failed building wheel for tornado
#   Running setup.py clean for tornado
# Failed to build stringcase bokeh validators PyYAML toolz retrying pyrsistent pandocfilters tornado
# Installing collected packages: zipp, importlib-resources, pytz, numpy, six, python-dateutil, pandas, retrying, plotly, colorlog, pyparsing, packaging, pyrsistent, attrs, importlib-metadata, setuptools, jsonschema, toolz, MarkupSafe, jinja2, entrypoints, altair, stringcase, urllib3, chardet, idna, certifi, requests, requests-toolbelt, click-spinner, pyarrow, click, orderedmultidict, furl, decorator, ipython-genutils, traitlets, jupyter-core, testpath, pygments, defusedxml, nbformat, webencodings, bleach, pandocfilters, mistune, nbconvert, pytoml, flit-core, ruamel.yaml.clib, ruamel.yaml, tabulate, PyYAML, pillow, tornado, typing-extensions, bokeh, validators, lxml, munch, dataclasses, dacite, cycler, kiwisolver, matplotlib, branca, folium, datapane
#   Running setup.py install for retrying ... done
#   Running setup.py install for pyrsistent ... done
#   Running setup.py install for toolz ... done
#   Running setup.py install for stringcase ... done
#   Running setup.py install for pandocfilters ... done
#   Running setup.py install for PyYAML ... done
#   Running setup.py install for tornado ... done
#   Running setup.py install for bokeh ... done

# %%
# basic modules
import geopandas as gpd
import pandas as pd 
import json 
import glob 
import os 
# visualizaztion modules 
from bokeh.resources import INLINE 
from bokeh.io import output_notebook, show, output_file 
from bokeh.plotting import figure 
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar 
from bokeh.palettes import brewer,mpl 
# interactive visualization models 
from bokeh.io import curdoc, output_notebook 
from bokeh.models import Slider, HoverTool 
from bokeh.layouts import widgetbox, row, column
import datapane as dp

# %%
# dados
df = pd.read_csv('/content/drive/My Drive/Pibiti_2019 - Notebooks (Análise e Visualizações)/drive_dados/parcela_media_ano.csv')
gdf = gpd.read_file('/content/drive/My Drive/Pibiti_2019 - Notebooks (Análise e Visualizações)/drive_dados/rideTotal2.shp')

# %%
# Função para retornar um json
def json_data(selectYear):
    ano = selectYear
    dfYear = df[df['ANO'] == ano]
    merged = gdf.merge(dfYear, left_on ='NM_MUNICIP', right_on ='NOME_MUNICIPIO', how ='left')
    merged['Valor'] = merged.VALOR_PARCELA.fillna("N/A")
    del merged['NOME_MUNICIPIO']
    del merged['VALOR_PARCELA']
    merged_json = json.loads(merged.to_json())
    json_data = json.dumps(merged_json)
    return json_data

# %%
# Bokeh + Datapane - 2013
# Input GeoJSON source that contains features for plotting.
# Select a default year to show on first display.
geosource = GeoJSONDataSource(geojson = json_data(2013))

# Define a sequential multi-hue color palette.
# I chose the Plasma theme because 10 would map to yellow :)
palette = mpl['Plasma'][10]

# Instantiate LinearColorMapper that maps numbers to a sequence of colors.
color_mapper = LinearColorMapper(palette = palette, low = 100, high = 250)

# Add the hovering tooltips.
hover = HoverTool(tooltips = [ ('Cidade','@NM_MUNICIP'),('Valor', '@Valor')])

# Create the color bar. 
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=10,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')

# Create the figure object.
p = figure(title = 'Valor médio do benefício - 2013', plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [hover])
# Remove the grid lines. 
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
# Increase the title font size.
p.title.text_font_size = '12pt'

# Add the patch renderer to the figure. 
# Notice that this is where you provide the Score column from the json_data and the color mapper.
p.patches('xs','ys', source = geosource,fill_color = {'field' :'Valor', 'transform' : color_mapper}, line_color = 'white', line_width = 0.5, fill_alpha =1)

# Place the color bar below the map.
p.add_layout(color_bar, 'below')

# Define the callback function.
# This is what will be called when the slider value changes.
def update_plot(attr, old, new):
    yr = slider.value
    new_data = json_data((yr))
    geosource.geojson = new_data
    p.title.text = 'Valor médio do benefício por cidade da RIDE' %yr
    
# Make a slider object.
slider = Slider(title = 'Year',start = 2013, end = 2019, step = 1, value = 2013)
slider.on_change('value', update_plot)

# Make a column layout of widgetbox (slider) and plot, and add it to the current document
layout = row(p,column(slider))
curdoc().add_root(layout)

# Show the figure.
# output_notebook(INLINE)
# show(layout)

# %%
# Bokeh + Datapane - 2014
# Input GeoJSON source that contains features for plotting.
# Select a default year to show on first display.
geosource = GeoJSONDataSource(geojson = json_data(2014))

# Define a sequential multi-hue color palette.
# I chose the Plasma theme because 10 would map to yellow :)
palette = mpl['Plasma'][10]

# Instantiate LinearColorMapper that maps numbers to a sequence of colors.
color_mapper = LinearColorMapper(palette = palette, low = 100, high = 250)

# Add the hovering tooltips.
hover = HoverTool(tooltips = [ ('Cidade','@NM_MUNICIP'),('Valor', '@Valor')])

# Create the color bar. 
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=10,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')

# Create the figure object.
p2 = figure(title = 'Valor médio do benefício - 2014', plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [hover])
# Remove the grid lines. 
p2.xgrid.grid_line_color = None
p2.ygrid.grid_line_color = None
# Increase the title font size.
p2.title.text_font_size = '12pt'

# Add the patch renderer to the figure. 
# Notice that this is where you provide the Score column from the json_data and the color mapper.
p2.patches('xs','ys', source = geosource,fill_color = {'field' :'Valor', 'transform' : color_mapper}, line_color = 'white', line_width = 0.5, fill_alpha =1)

# Place the color bar below the map.
p2.add_layout(color_bar, 'below')

# Define the callback function.
# This is what will be called when the slider value changes.
# def update_plot(attr, old, new):
#     yr = slider.value
#     new_data = json_data((yr))
#     geosource.geojson = new_data
#     p.title.text = 'Valor médio do benefício por cidade da RIDE' %yr
    
# Make a slider object.
# slider = Slider(title = 'Year',start = 2013, end = 2019, step = 1, value = 2013)
# slider.on_change('value', update_plot)

# Make a column layout of widgetbox (slider) and plot, and add it to the current document
layout = row(p2)
curdoc().add_root(layout)

# %%
# Bokeh + Datapane - 2015

geosource = GeoJSONDataSource(geojson = json_data(2015))
palette = mpl['Plasma'][10]
color_mapper = LinearColorMapper(palette = palette, low = 100, high = 250)
hover = HoverTool(tooltips = [ ('Cidade','@NM_MUNICIP'),('Valor', '@Valor')])
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=10,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')
p3 = figure(title = 'Valor médio do benefício - 2015', plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [hover])
# Remove the grid lines. 
p3.xgrid.grid_line_color = None
p3.ygrid.grid_line_color = None
# Increase the title font size.
p3.title.text_font_size = '12pt'

# Add the patch renderer to the figure. 
# Notice that this is where you provide the Score column from the json_data and the color mapper.
p3.patches('xs','ys', source = geosource,fill_color = {'field' :'Valor', 'transform' : color_mapper}, line_color = 'white', line_width = 0.5, fill_alpha =1)

# Place the color bar below the map.
p3.add_layout(color_bar, 'below')

# Make a column layout of widgetbox (slider) and plot, and add it to the current document
layout = row(p3)
curdoc().add_root(layout)

# %%
# Bokeh + Datapane - 2016

geosource = GeoJSONDataSource(geojson = json_data(2016))
palette = mpl['Plasma'][10]
color_mapper = LinearColorMapper(palette = palette, low = 100, high = 250)
hover = HoverTool(tooltips = [ ('Cidade','@NM_MUNICIP'),('Valor', '@Valor')])
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=10,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')
p4 = figure(title = 'Valor médio do benefício - 2016', plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [hover])
# Remove the grid lines. 
p4.xgrid.grid_line_color = None
p4.ygrid.grid_line_color = None
# Increase the title font size.
p4.title.text_font_size = '12pt'

# Add the patch renderer to the figure. 
# Notice that this is where you provide the Score column from the json_data and the color mapper.
p4.patches('xs','ys', source = geosource,fill_color = {'field' :'Valor', 'transform' : color_mapper}, line_color = 'white', line_width = 0.5, fill_alpha =1)

# Place the color bar below the map.
p4.add_layout(color_bar, 'below')

# Make a column layout of widgetbox (slider) and plot, and add it to the current document
layout = row(p4)
curdoc().add_root(layout)

# %%
# Bokeh + Datapane - 2017

geosource = GeoJSONDataSource(geojson = json_data(2017))
palette = mpl['Plasma'][10]
color_mapper = LinearColorMapper(palette = palette, low = 100, high = 250)
hover = HoverTool(tooltips = [ ('Cidade','@NM_MUNICIP'),('Valor', '@Valor')])
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=10,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')
p5 = figure(title = 'Valor médio do benefício - 2017', plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [hover])
# Remove the grid lines. 
p5.xgrid.grid_line_color = None
p5.ygrid.grid_line_color = None
# Increase the title font size.
p5.title.text_font_size = '12pt'

# Add the patch renderer to the figure. 
# Notice that this is where you provide the Score column from the json_data and the color mapper.
p5.patches('xs','ys', source = geosource,fill_color = {'field' :'Valor', 'transform' : color_mapper}, line_color = 'white', line_width = 0.5, fill_alpha =1)

# Place the color bar below the map.
p5.add_layout(color_bar, 'below')

# Make a column layout of widgetbox (slider) and plot, and add it to the current document
layout = row(p5)
curdoc().add_root(layout)

# %%
# Bokeh + Datapane - 2018

geosource = GeoJSONDataSource(geojson = json_data(2018))
palette = mpl['Plasma'][10]
color_mapper = LinearColorMapper(palette = palette, low = 100, high = 250)
hover = HoverTool(tooltips = [ ('Cidade','@NM_MUNICIP'),('Valor', '@Valor')])
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=10,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')
p6 = figure(title = 'Valor médio do benefício - 2018', plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [hover])
# Remove the grid lines. 
p6.xgrid.grid_line_color = None
p6.ygrid.grid_line_color = None
# Increase the title font size.
p6.title.text_font_size = '12pt'

# Add the patch renderer to the figure. 
# Notice that this is where you provide the Score column from the json_data and the color mapper.
p6.patches('xs','ys', source = geosource,fill_color = {'field' :'Valor', 'transform' : color_mapper}, line_color = 'white', line_width = 0.5, fill_alpha =1)

# Place the color bar below the map.
p6.add_layout(color_bar, 'below')

# Make a column layout of widgetbox (slider) and plot, and add it to the current document
layout = row(p6)
curdoc().add_root(layout)

# %%
# Bokeh + Datapane - 2019

geosource = GeoJSONDataSource(geojson = json_data(2019))
palette = mpl['Plasma'][10]
color_mapper = LinearColorMapper(palette = palette, low = 100, high = 250)
hover = HoverTool(tooltips = [ ('Cidade','@NM_MUNICIP'),('Valor', '@Valor')])
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=10,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')
p7 = figure(title = 'Valor médio do benefício - 2019', plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [hover])
# Remove the grid lines. 
p7.xgrid.grid_line_color = None
p7.ygrid.grid_line_color = None
# Increase the title font size.
p7.title.text_font_size = '12pt'

# Add the patch renderer to the figure. 
# Notice that this is where you provide the Score column from the json_data and the color mapper.
p7.patches('xs','ys', source = geosource,fill_color = {'field' :'Valor', 'transform' : color_mapper}, line_color = 'white', line_width = 0.5, fill_alpha =1)

# Place the color bar below the map.
p7.add_layout(color_bar, 'below')

# Make a column layout of widgetbox (slider) and plot, and add it to the current document
layout = row(p7)
curdoc().add_root(layout)

# %%
# DATAPANE

# Show the figure.
r = dp.Report(

    dp.Markdown('## Valor médio do benefício por ano'), #add description to the report
    dp.Plot(p), #create a chart  
    dp.Plot(p2), #create a chart
    dp.Plot(p3), #create a chart
    dp.Plot(p4), #create a chart
    dp.Plot(p5), #create a chart
    dp.Plot(p6), #create a chart
    dp.Plot(p7), #create a chart
    dp.Markdown('## Tabela com os valores recebidos'), #dados
    dp.Table(df)
  
)

#Publish your report. Make sure to have visibility='PUBLIC' if you want to share your report
#r.publish(name='stock_report', visibility='PUBLIC')
r.save(path='relatório.html')

# %%
# !datapane login --server=https://datapane.com/ --token=9034b88d6f6ad54400fceb9c06c91ed208852dd0
# Out:
# Logged in to https://datapane.com/ as marcos
