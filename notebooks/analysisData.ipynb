# %% [markdown]
# # Estudo sobre dados retirados do Neo4j

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.cluster import KMeans
import warnings
import os
import csv
from collections import OrderedDict
pd.set_option("display.max_rows", 2000)
warnings.filterwarnings("ignore")

# %%
#Lendo o arquivo e criando um dataframe
df = pd.read_csv('./dataset_analysis/dataset_2.csv', low_memory=False)
#df = df.astype('category')
df.head(10)
# Out:
#    identificacao   estado  qtdEstado  mesRefe
# 0    16112650429  [MG,DF]          2   201303
# 1    16189810986  [GO,DF]          2   201303
# 2    16460835889  [MG,DF]          2   201303
# 3    12000654365  [GO,DF]          2   201303
# 4    16440022211  [GO,DF]          2   201303
# 5    12516841126  [GO,DF]          2   201301
# 6    16476546539  [GO,DF]          2   201301
# 7    12522299702  [GO,DF]          2   201302
# 8    12522299702  [GO,DF]          2   201301
# 9    16381859084  [GO,DF]          2   201302

# %%
#Removendo colchetes
df['estado'] = df['estado'].str.strip('[]').astype(str)

# %%
df.head(1000)
# Out:
#     identificacao estado  qtdEstado  mesRefe
# 0     16112650429  MG,DF          2   201303
# 1     16189810986  GO,DF          2   201303
# 2     16460835889  MG,DF          2   201303
# 3     12000654365  GO,DF          2   201303
# 4     16440022211  GO,DF          2   201303
# 5     12516841126  GO,DF          2   201301
# 6     16476546539  GO,DF          2   201301
# 7     12522299702  GO,DF          2   201302
# 8     12522299702  GO,DF          2   201301
# 9     16381859084  GO,DF          2   201302
# 10    16381859084  GO,DF          2   201301
# 11    16447163341  GO,DF          2   201303
# 12    16447163341  GO,DF          2   201302
# 13    16447163341  GO,DF          2   201301
# 14    12917479274  GO,DF          2   201301
# 15    16669310677  MG,GO          2   201302
# 16    16669310677  MG,GO          2   201301
# 17    16147773411  GO,MG          2   201302
# 18    16147773411  GO,MG          2   201301
# 19    12581046270  GO,DF          2   201401

# %%
# Contagem de Amostras por Estado:
plt.figure(1 , figsize = (15 , 8))
sns.countplot(y = 'estado' , data = df)
plt.show()

# %%
#Criando dataframe go_df
go_df = df.loc[(df['estado']) == 'GO,DF']

# %%
go_df.shape
# Out:
# (150, 3)

# %%
#Criando dataframe go_mg
go_mg = df.loc[(df['estado']) == 'GO,MG']

# %%
go_mg.shape
# Out:
# (16, 3)

# %%
#Criando dataframe df_mg
df_mg = df.loc[(df['estado']) == 'DF,MG']

# %%
df_mg.shape
# Out:
# (2, 3)

# %%
#Criando dataframe df_go
df_go = df.loc[(df['estado']) == 'DF,GO']

# %%
df_go.shape
# Out:
# (25, 3)

# %%
#Criando dataframe mg_go
mg_go = df.loc[(df['estado']) == 'MG,GO']
mg_go.shape
# Out:
# (1, 3)

# %%
#Criando dataframe mg_go
mg_df = df.loc[(df['estado']) == 'MG,DF']
mg_df.shape
# Out:
# (7, 3)

# %%
#Juntando os dataframes
df_1 = pd.merge(go_df,go_mg, on = ['identificacao','estado','qtdEstado'], how="outer")
df_2 = pd.merge(mg_df,mg_go, on = ['identificacao','estado','qtdEstado'], how="outer")
df_3 = pd.merge(df_go,df_mg, on = ['identificacao','estado','qtdEstado'], how="outer")
df_12 = pd.merge(df_1,df_2, on = ['identificacao','estado','qtdEstado'], how="outer")
df_estados = pd.merge(df_12,df_3, on = ['identificacao','estado','qtdEstado'], how="outer")

# %%
df_estados.shape
# Out:
# (201, 3)

# %%
df_estados.groupby('estado').count()
# Out:
#         identificacao  qtdEstado
# estado
# DF,GO              25         25
# DF,MG               2          2
# GO,DF             150        150
# GO,MG              16         16
# MG,DF               7          7
# MG,GO               1          1

# %%
gp = df_estados.groupby(['estado'])
gp.head(1)
# Out:
#      identificacao estado  qtdEstado
# 0      21265277372  GO,DF          2
# 150    16669310677  GO,MG          5
# 166    16112650429  MG,DF          4
# 173    16011383425  MG,GO          2
# 174    12522299702  DF,GO          5
# 199    16591042963  DF,MG          2

# %%
df2 = df_estados

# %%
df2['qtd'] = 0

# %%
df2.groupby('estado').count()
# Out:
#         identificacao  qtdEstado  qtd
# estado
# DF,GO              25         25   25
# DF,MG               2          2    2
# GO,DF             150        150  150
# GO,MG              16         16   16
# MG,DF               7          7    7
# MG,GO               1          1    1

# %%
data  = OrderedDict({
    'Estado':['DF-GO','DF-MG','GO-DF','GO-MG','MG-DF','MG-GO'],
    'Qtd':[25,2,150,16,7,1]
})
df_qtd = pd.DataFrame(data)
df_qtd
# Out:
#   Estado  Qtd
# 0  DF-GO   25
# 1  DF-MG    2
# 2  GO-DF  150
# 3  GO-MG   16
# 4  MG-DF    7
# 5  MG-GO    1

# %%
df2
# Out:
#      identificacao estado  qtdEstado  qtd
# 0      21265277372  GO,DF          2    0
# 1      16136756340  GO,DF          2    0
# 2      21204799646  GO,DF          2    0
# 3      13161402277  GO,DF          2    0
# 4      16136743508  GO,DF          2    0
# 5      13011338816  GO,DF          2    0
# 6      21240645742  GO,DF          2    0
# 7      13081937271  GO,DF          3    0
# 8      16153414622  GO,DF          2    0
# 9      20409466047  GO,DF          2    0
# 10     16033026463  GO,DF          2    0
# 11     13082746275  GO,DF          2    0
# 12     12835143272  GO,DF          2    0
# 13     14496575279  GO,DF          2    0
# 14     16677772102  GO,DF          2    0
# 15     12800977274  GO,DF          2    0
# 16     12460358409  GO,DF          2    0
# 17     16487794482  GO,DF          2    0
# 18     16395129857  GO,DF          2    0
# 19     16518218224  GO,DF          2    0
# 20     13040640274  GO,DF          2    0
# 21     16476245288  GO,DF          2    0
# 22     16027218356  GO,DF          2    0
# 23     16033129505  GO,DF          2    0
# 24     12789674274  GO,DF          2    0
# 25     16129778008  GO,DF          2    0
# 26     21206000874  GO,DF          2    0
# 27     20036295102  GO,DF          2    0
# 28     21046777132  GO,DF          2    0
# 29     12547333831  GO,DF          2    0
# 30     16079508843  GO,DF          2    0
# 31     16136826330  GO,DF          2    0
# 32     21205057074  GO,DF          2    0
# 33     20340117863  GO,DF          2    0
# 34     16033228481  GO,DF          2    0
# 35     16279445411  GO,DF          2    0
# 36     22013334752  GO,DF          2    0
# 37     20153502260  GO,DF          2    0
# 38     16262681311  GO,DF          3    0
# 39     16303317104  GO,DF          2    0
# 40     16283472274  GO,DF          2    0
# 41     16266267331  GO,DF          2    0
# 42     13610485271  GO,DF          3    0
# 43     16079651425  GO,DF          2    0
# 44     16264665038  GO,DF          2    0
# 45     16319718715  GO,DF          2    0
# 46     12738061275  GO,DF          2    0
# 47     16331094734  GO,DF          2    0
# 48     16268917139  GO,DF          3    0
# 49     16207378769  GO,DF          3    0
# 50     16251833670  GO,DF          2    0
# 51     16266347882  GO,DF          2    0
# 52     22009106651  GO,DF          2    0
# 53     16189810986  GO,DF          4    0
# 54     16207405502  GO,DF          2    0
# 55     16302003351  GO,DF          2    0
# 56     20309927204  GO,DF          2    0
# 57     12904067274  GO,DF          2    0
# 58     12920600275  GO,DF          2    0
# 59     10610150208  GO,DF          2    0
# 60     22002082609  GO,DF          2    0
# 61     16207552629  GO,DF          2    0
# 62     16509866448  GO,DF          2    0
# 63     16476183789  GO,DF          2    0
# 64     20429974927  GO,DF          2    0
# 65     16439829204  GO,DF          2    0
# 66     22810246474  GO,DF          2    0
# 67     16477550203  GO,DF          2    0
# 68     16479377908  GO,DF          3    0
# 69     16442623727  GO,DF          2    0
# 70     20389178572  GO,DF          2    0
# 71     12320733835  GO,DF          3    0
# 72     16438007154  GO,DF          2    0
# 73     20159310444  GO,DF          2    0
# 74     13026739277  GO,DF          2    0
# 75     16442642098  GO,DF          2    0
# 76     16439977742  GO,DF          2    0
# 77     17058519453  GO,DF          2    0
# 78     13488744271  GO,DF          2    0
# 79     12697705270  GO,DF          2    0
# 80     13173586270  GO,DF          2    0
# 81     22809436389  GO,DF          3    0
# 82     13942189274  GO,DF          3    0
# 83     12000654365  GO,DF          4    0
# 84     12793923275  GO,DF          2    0
# 85     16396146046  GO,DF          2    0
# 86     22812987331  GO,DF          3    0
# 87     12522226950  GO,DF          2    0
# 88     16397983006  GO,DF          2    0
# 89     20726411285  GO,DF          2    0
# 90     16517823582  GO,DF          2    0
# 91     16477579171  GO,DF          2    0
# 92     16440022211  GO,DF          4    0
# 93     12345968259  GO,DF          2    0
# 94     16513876797  GO,DF          2    0
# 95     16442456243  GO,DF          3    0
# 96     16375511349  GO,DF          3    0
# 97     12516841126  GO,DF          3    0
# 98     16476546539  GO,DF          3    0
# 99     16477802032  GO,DF          2    0
# 100    12670203274  GO,DF          2    0
# 101    16442648843  GO,DF          2    0
# 102    21063014974  GO,DF          2    0
# 103    16476615646  GO,DF          3    0
# 104    16442664377  GO,DF          2    0
# 105    13343214271  GO,DF          2    0
# 106    12868611275  GO,DF          3    0
# 107    16447163341  GO,DF          6    0
# 108    16381862212  GO,DF          2    0
# 109    16402668444  GO,DF          2    0
# 110    16459873020  GO,DF          3    0
# 111    12439947158  GO,DF          3    0
# 112    13557438316  GO,DF          3    0
# 113    16548180101  GO,DF          2    0
# 114    16442502520  GO,DF          3    0
# 115    23611547669  GO,DF          2    0
# 116    12348688982  GO,DF          2    0
# 117    12636381270  GO,DF          2    0
# 118    16618236461  GO,DF          2    0
# 119    12917479274  GO,DF          4    0
# 120    16581126501  GO,DF          2    0
# 121    12763548271  GO,DF          2    0
# 122    16652959039  GO,DF          2    0
# 123    16657304162  GO,DF          3    0
# 124    20630140639  GO,DF          2    0
# 125    12847629272  GO,DF          2    0
# 126    12990294270  GO,DF          3    0
# 127    16651593685  GO,DF          2    0
# 128    12429529000  GO,DF          3    0
# 129    16674627365  GO,DF          2    0
# 130    16649526739  GO,DF          2    0
# 131    12786204277  GO,DF          2    0
# 132    21015539337  GO,DF          2    0
# 133    16614015886  GO,DF          2    0
# 134    12590856271  GO,DF          2    0
# 135    16691909330  GO,DF          2    0
# 136    16618479267  GO,DF          2    0
# 137    16651777859  GO,DF          2    0
# 138    16661450127  GO,DF          2    0
# 139    13704042314  GO,DF          2    0
# 140    12721569270  GO,DF          2    0
# 141    16647139436  GO,DF          2    0
# 142    12715290480  GO,DF          3    0
# 143    16651905709  GO,DF          2    0
# 144    16614068033  GO,DF          2    0
# 145    12924059277  GO,DF          2    0
# 146    16651888251  GO,DF          2    0
# 147    19018457798  GO,DF          2    0
# 148    20153465721  GO,DF          2    0
# 149    16595500249  GO,DF          3    0
# 150    16669310677  GO,MG          5    0
# 151    16698158160  GO,MG          2    0
# 152    20791317948  GO,MG          3    0
# 153    21247386734  GO,MG          3    0
# 154    20705694989  GO,MG          3    0
# 155    20119538657  GO,MG          2    0
# 156    16153761381  GO,MG          2    0
# 157    22811804551  GO,MG          3    0
# 158    16486118327  GO,MG          2    0
# 159    16658876011  GO,MG          4    0
# 160    16114718616  GO,MG          3    0
# 161    16147773411  GO,MG          5    0
# 162    16317893773  GO,MG          2    0
# 163    19007597283  GO,MG          2    0
# 164    16456178836  GO,MG          2    0
# 165    16012518197  GO,MG          3    0
# 166    16112650429  MG,DF          4    0
# 167    16297572810  MG,DF          2    0
# 168    16476180100  MG,DF          2    0
# 169    16439826191  MG,DF          2    0
# 170    16511811558  MG,DF          2    0
# 171    16460835889  MG,DF          4    0
# 172    20791571356  MG,DF          2    0
# 173    16011383425  MG,GO          2    0
# 174    12522299702  DF,GO          5    0
# 175    16381859084  DF,GO          5    0
# 176    16518999005  DF,GO          3    0
# 177    16607410147  DF,GO          2    0
# 178    12376027359  DF,GO          2    0
# 179    23604741471  DF,GO          2    0
# 180    16686116441  DF,GO          3    0
# 181    16581428842  DF,GO          2    0
# 182    12512677445  DF,GO          2    0
# 183    13095175271  DF,GO          2    0
# 184    17068342882  DF,GO          3    0
# 185    20619603814  DF,GO          2    0
# 186    12876684278  DF,GO          2    0
# 187    20445565939  DF,GO          3    0
# 188    16592796120  DF,GO          2    0
# 189    21029691519  DF,GO          3    0
# 190    16557412311  DF,GO          3    0
# 191    12528222442  DF,GO          4    0
# 192    16485963856  DF,GO          3    0
# 193    16552142111  DF,GO          3    0
# 194    20163458841  DF,GO          3    0
# 195    16629518854  DF,GO          2    0
# 196    16653576567  DF,GO          3    0
# 197    16558173043  DF,GO          2    0
# 198    14592763277  DF,GO          2    0
# 199    16591042963  DF,MG          2    0
# 200    20326808315  DF,MG          2    0

# %% [markdown]
# ## Visualização

# %%
#print(list(df_qtd['Estado']))
y_axis = (df_qtd['Qtd'].values)
x_axis = list(df_qtd['Estado'])
width_n = 0.3

# %%
plt.figure(figsize=(8,5))
plt.bar(x_axis, y_axis, width=width_n, color='green')
plt.style.use('fivethirtyeight')
plt.title('Janeiro de 2014', y = 1.08)
plt.annotate(df_qtd.loc[0,'Qtd'], xy=('DF-GO',df_qtd.loc[0,'Qtd'] * (1.2)), ha='center')
plt.annotate(df_qtd.loc[1,'Qtd'], xy=('DF-MG',df_qtd.loc[0,'Qtd'] * (.5)), ha='center')
plt.annotate(df_qtd.loc[2,'Qtd'], xy=('GO-DF',df_qtd.loc[0,'Qtd'] * (6.2)), ha='center')
plt.annotate(df_qtd.loc[3,'Qtd'], xy=('GO-MG',df_qtd.loc[0,'Qtd']), ha='center')
plt.annotate(df_qtd.loc[4,'Qtd'], xy=('MG-DF',df_qtd.loc[0,'Qtd'] * (.5)), ha='center')
plt.annotate(df_qtd.loc[5,'Qtd'], xy=('MG-GO',df_qtd.loc[0,'Qtd'] * (.5)), ha='center')

plt.show()

# %% [markdown]
# ## Clusterização

# %%
df.head()
# Out:
#    identificacao estado  qtdEstado
# 0    16686120759     DF         11
# 1    21259030271     DF         10
# 2    16005405056     DF         10
# 3    20107035361     DF          7
# 4    23606526640     DF          7

# %%
# Idade vs Renda Anual:
plt.figure(1 , figsize = (15 , 6))
for estado in ['GO','DF','MG','DF,MG','DF,GO','GO,MG','GO,DF','MG,GO','MG,DF']:
    plt.scatter(x = 'qtdEstado' , y = 'estado' , data = df[df['estado'] == estado] ,
                s = 100 , alpha = 0.5 , label = estado)
plt.xlabel('qtdEstado'), plt.ylabel('estado') 
plt.title('Teste')
plt.legend()
plt.show()
